# %%
import pandas as pd
import os
import sqlalchemy

# %%
os.getcwd()
# Out:
# '/home/dell'

# %%
os.chdir("/home/dell/Desktop")

# %%
data = pd.read_csv("/home/dell/Desktop/a.us.txt",parse_dates = ['Date'] , index_col = ['Date'])

# %%
data.head()
# Out:
#               Open    High     Low   Close    Volume  OpenInt
# Date
# 1999-11-18  30.713  33.754  27.002  29.702  66277506        0
# 1999-11-19  28.986  29.027  26.872  27.257  16142920        0
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0
# 1999-11-23  28.688  29.446  27.002  27.002   6332082        0
# 1999-11-24  27.083  28.309  27.002  27.717   5132147        0

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.index
# Out:
# DatetimeIndex(['1999-11-18', '1999-11-19', '1999-11-22', '1999-11-23',
#                '1999-11-24', '1999-11-26', '1999-11-29', '1999-11-30',
#                '1999-12-01', '1999-12-02',
#                ...
#                '2017-10-30', '2017-10-31', '2017-11-01', '2017-11-02',
#                '2017-11-03', '2017-11-06', '2017-11-07', '2017-11-08',
#                '2017-11-09', '2017-11-10'],
#               dtype='datetime64[ns]', name='Date', length=4521, freq=None)

# %%
data['2017-01-01':'2017-01-07']
# Out:
#               Open    High     Low   Close   Volume  OpenInt
# Date
# 2017-01-03  45.621  46.436  45.434  46.178  1751589        0
# 2017-01-04  46.615  47.063  46.502  46.784  1833563        0
# 2017-01-05  46.735  46.754  46.044  46.228  1513918        0
# 2017-01-06  46.318  47.747  46.248  47.668  2902875        0

# %%
# %matplotlib inline
data.Open.resample('Y').mean()
# Out:
# Date
# 1999-12-31    32.071567
# 2000-12-31    47.174020
# 2001-12-31    22.496081
# 2002-12-31    15.567664
# 2003-12-31    13.628798
# 2004-12-31    18.158853
# 2005-12-31    18.237806
# 2006-12-31    22.784295
# 2007-12-31    24.210339
# 2008-12-31    20.370269
# 2009-12-31    14.712827
# 2010-12-31    21.928754
# 2011-12-31    27.945421
# 2012-12-31    27.064528
# 2013-12-31    32.014155
# 2014-12-31    39.257421
# 2015-12-31    38.640250
# 2016-12-31    42.768500
# 2017-12-31    57.829661
# Freq: A-DEC, Name: Open, dtype: float64

# %%
data['2017'].Open.resample('Q').mean().plot()

# %%
data['2017'].Open.resample('Q').mean().plot(kind = 'bar')

# %%
data['2015'].Open.resample('M').mean().plot(kind = 'line')

# %%
data['2017'].Open.plot()

# %%
data = data.asfreq('D' , method='pad'  )  #removing holidays and continuing same values as last day

# %%
data.head()
# Out:
#               Open    High     Low   Close    Volume  OpenInt
# Date
# 1999-11-18  30.713  33.754  27.002  29.702  66277506        0
# 1999-11-19  28.986  29.027  26.872  27.257  16142920        0
# 1999-11-20  28.986  29.027  26.872  27.257  16142920        0
# 1999-11-21  28.986  29.027  26.872  27.257  16142920        0
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0

# %%
data['2017-01']
# Out:
#               Open    High     Low   Close   Volume  OpenInt
# Date
# 2017-01-01  45.454  45.513  45.071  45.254  1224312        0
# 2017-01-02  45.454  45.513  45.071  45.254  1224312        0
# 2017-01-03  45.621  46.436  45.434  46.178  1751589        0
# 2017-01-04  46.615  47.063  46.502  46.784  1833563        0
# 2017-01-05  46.735  46.754  46.044  46.228  1513918        0
# 2017-01-06  46.318  47.747  46.248  47.668  2902875        0
# 2017-01-07  46.318  47.747  46.248  47.668  2902875        0
# 2017-01-08  46.318  47.747  46.248  47.668  2902875        0
# 2017-01-09  47.688  48.229  47.583  47.817  2592719        0
# 2017-01-10  48.016  48.214  47.500  47.777  1571087        0
# 2017-01-11  47.708  49.148  47.628  48.920  5662313        0
# 2017-01-12  48.572  48.572  47.658  48.194  3299081        0
# 2017-01-13  48.274  48.523  48.085  48.363  1579157        0
# 2017-01-14  48.274  48.523  48.085  48.363  1579157        0
# ...

# %%
data['2017-01'].asfreq('M' , method='pad'  )
# Out:
#                              Open    High     Low   Close   Volume  OpenInt
# Date
# 2017-01-31 00:00:00-05:00  47.718  48.815  47.688  48.641  2569850        0

# %%
import numpy as np
ts = pd.Series(np.random.randint(1,10000,len(data) ) , index = date)
ts.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     398                         if cls is not object \
#     399                                 and callable(cls.__dict__.get('__repr__')):
# --> 400                             return _repr_pprint(obj, self, cycle)
#     401
#     402             return _default_pprint(obj, self, cycle)
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
data.head()
# Out:
#               Open    High     Low   Close    Volume  OpenInt
# Date
# 1999-11-18  30.713  33.754  27.002  29.702  66277506        0
# 1999-11-19  28.986  29.027  26.872  27.257  16142920        0
# 1999-11-20  28.986  29.027  26.872  27.257  16142920        0
# 1999-11-21  28.986  29.027  26.872  27.257  16142920        0
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0

# %%
data.index
# Out:
# DatetimeIndex(['1999-11-18', '1999-11-19', '1999-11-20', '1999-11-21',
#                '1999-11-22', '1999-11-23', '1999-11-24', '1999-11-25',
#                '1999-11-26', '1999-11-27',
#                ...
#                '2017-11-01', '2017-11-02', '2017-11-03', '2017-11-04',
#                '2017-11-05', '2017-11-06', '2017-11-07', '2017-11-08',
#                '2017-11-09', '2017-11-10'],
#               dtype='datetime64[ns]', name='Date', length=6568, freq='D')

# %%
data = data.tz_localize(tz = 'US/Eastern')  #changing time zone and making i ttz aware from naive
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-d357d8fe8036> in <module>()
# ----> 1 data = data.tz_localize(tz = 'US/Eastern')  #changing time zone and making i ttz aware from naive
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in tz_localize(self, tz, axis, level, copy, ambiguous)
#    8181             if level not in (None, 0, ax.name):
#    8182                 raise ValueError("The level {0} is not valid".format(level))
# -> 8183             ax = _tz_localize(ax, tz, ambiguous)
#    8184
#    8185         result = self._constructor(self._data, copy=copy)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _tz_localize(ax, tz, ambiguous)
#    8169                     ax = DatetimeIndex([], tz=tz)
#    8170             else:
# -> 8171                 ax = ax.tz_localize(tz, ambiguous=ambiguous)
# ...

# %%
data.index
# Out:
# DatetimeIndex(['1999-11-18', '1999-11-19', '1999-11-20', '1999-11-21',
#                '1999-11-22', '1999-11-23', '1999-11-24', '1999-11-25',
#                '1999-11-26', '1999-11-27',
#                ...
#                '2017-11-01', '2017-11-02', '2017-11-03', '2017-11-04',
#                '2017-11-05', '2017-11-06', '2017-11-07', '2017-11-08',
#                '2017-11-09', '2017-11-10'],
#               dtype='datetime64[ns]', name='Date', length=6568, freq='D')

# %%
data.head()
# Out:
#               Open    High     Low   Close    Volume  OpenInt
# Date
# 1999-11-18  30.713  33.754  27.002  29.702  66277506        0
# 1999-11-19  28.986  29.027  26.872  27.257  16142920        0
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0
# 1999-11-23  28.688  29.446  27.002  27.002   6332082        0
# 1999-11-24  27.083  28.309  27.002  27.717   5132147        0

# %%
data.drop('OpenInt',axis = 1 , inplace = True)

# %%
data.head()
# Out:
#               Open    High     Low   Close    Volume  prevDay
# Date
# 1999-11-18  30.713  33.754  27.002  29.702  66277506      NaN
# 1999-11-19  28.986  29.027  26.872  27.257  16142920   30.713
# 1999-11-22  27.886  29.702  27.044  29.702   6970266   28.986
# 1999-11-23  28.688  29.446  27.002  27.002   6332082   27.886
# 1999-11-24  27.083  28.309  27.002  27.717   5132147   28.688

# %%
data['prevDay'] = data['Open'].shift(1) #calc one day change

# %%
data.head()
# Out:
#               Open    High     Low   Close    Volume  OpenInt  prevDay
# Date
# 1999-11-18  30.713  33.754  27.002  29.702  66277506        0      NaN
# 1999-11-19  28.986  29.027  26.872  27.257  16142920        0   30.713
# 1999-11-20  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-21  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0   28.986

# %%
data['OneDayChange'] = data['Open']  - data['prevDay']

# %%
data.head()
# Out:
#               Open    High     Low   Close    Volume  OpenInt  prevDay  \
# Date
# 1999-11-18  30.713  33.754  27.002  29.702  66277506        0      NaN
# 1999-11-19  28.986  29.027  26.872  27.257  16142920        0   30.713
# 1999-11-20  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-21  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0   28.986
#
#             OneDayChange
# Date
# 1999-11-18           NaN
# 1999-11-19        -1.727
# 1999-11-20         0.000
# 1999-11-21         0.000
# 1999-11-22        -1.100

# %%
rows , coloumns = data.shape

# %%
data[2:10]
# Out:
#               Open    High     Low   Close    Volume  OpenInt  prevDay  \
# Date
# 1999-11-20  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-21  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0   28.986
# 1999-11-23  28.688  29.446  27.002  27.002   6332082        0   27.886
# 1999-11-24  27.083  28.309  27.002  27.717   5132147        0   28.688
# 1999-11-25  27.083  28.309  27.002  27.717   5132147        0   27.083
# 1999-11-26  27.594  28.012  27.509  27.807   1832635        0   27.083
# 1999-11-27  27.594  28.012  27.509  27.807   1832635        0   27.594
#
#             OneDayChange
# Date
# 1999-11-20         0.000
# 1999-11-21         0.000
# 1999-11-22        -1.100
# 1999-11-23         0.802
# 1999-11-24        -1.605
# 1999-11-25         0.000
# 1999-11-26         0.511
# 1999-11-27         0.000

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt', 'prevDay',
#        'OneDayChange'],
#       dtype='object')

# %%
data.drop(labels='OpenInt' , inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-65b9f93830b8> in <module>()
# ----> 1 data.drop(labels='OpenInt' , inplace = True)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# ...

# %%
data[2:10]
# Out:
#               Open    High     Low   Close    Volume  OpenInt  prevDay  \
# Date
# 1999-11-20  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-21  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0   28.986
# 1999-11-23  28.688  29.446  27.002  27.002   6332082        0   27.886
# 1999-11-24  27.083  28.309  27.002  27.717   5132147        0   28.688
# 1999-11-25  27.083  28.309  27.002  27.717   5132147        0   27.083
# 1999-11-26  27.594  28.012  27.509  27.807   1832635        0   27.083
# 1999-11-27  27.594  28.012  27.509  27.807   1832635        0   27.594
#
#             OneDayChange
# Date
# 1999-11-20         0.000
# 1999-11-21         0.000
# 1999-11-22        -1.100
# 1999-11-23         0.802
# 1999-11-24        -1.605
# 1999-11-25         0.000
# 1999-11-26         0.511
# 1999-11-27         0.000

# %%
data.describe
# Out:
# <bound method NDFrame.describe of               Open    High     Low   Close    Volume  OpenInt  prevDay  \
# Date
# 1999-11-18  30.713  33.754  27.002  29.702  66277506        0      NaN
# 1999-11-19  28.986  29.027  26.872  27.257  16142920        0   30.713
# 1999-11-20  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-21  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0   28.986
# 1999-11-23  28.688  29.446  27.002  27.002   6332082        0   27.886
# 1999-11-24  27.083  28.309  27.002  27.717   5132147        0   28.688
# 1999-11-25  27.083  28.309  27.002  27.717   5132147        0   27.083
# 1999-11-26  27.594  28.012  27.509  27.807   1832635        0   27.083
# 1999-11-27  27.594  28.012  27.509  27.807   1832635        0   27.594
# 1999-11-28  27.594  28.012  27.509  27.807   1832635        0   27.594
# 1999-11-29  27.676  28.650  27.380  28.432   4317826        0   27.594
# ...

# %%
data[data.High >= 25.5]
# Out:
#               Open    High     Low   Close    Volume  OpenInt  prevDay  \
# Date
# 1999-11-18  30.713  33.754  27.002  29.702  66277506        0      NaN
# 1999-11-19  28.986  29.027  26.872  27.257  16142920        0   30.713
# 1999-11-20  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-21  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0   28.986
# 1999-11-23  28.688  29.446  27.002  27.002   6332082        0   27.886
# 1999-11-24  27.083  28.309  27.002  27.717   5132147        0   28.688
# 1999-11-25  27.083  28.309  27.002  27.717   5132147        0   27.083
# 1999-11-26  27.594  28.012  27.509  27.807   1832635        0   27.083
# 1999-11-27  27.594  28.012  27.509  27.807   1832635        0   27.594
# 1999-11-28  27.594  28.012  27.509  27.807   1832635        0   27.594
# 1999-11-29  27.676  28.650  27.380  28.432   4317826        0   27.594
# ...

# %%
data.head()
# Out:
#               Open    High     Low   Close    Volume  OpenInt  prevDay  \
# Date
# 1999-11-18  30.713  33.754  27.002  29.702  66277506        0      NaN
# 1999-11-19  28.986  29.027  26.872  27.257  16142920        0   30.713
# 1999-11-20  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-21  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0   28.986
#
#             OneDayChange
# Date
# 1999-11-18           NaN
# 1999-11-19        -1.727
# 1999-11-20         0.000
# 1999-11-21         0.000
# 1999-11-22        -1.100

# %%
data[['Open']][data.Open == data['Open'].max() ] #print max open value
# Out:
#              Open
# Date
# 2000-03-07  105.3

# %%
data.index
# Out:
# DatetimeIndex(['1999-11-18', '1999-11-19', '1999-11-20', '1999-11-21',
#                '1999-11-22', '1999-11-23', '1999-11-24', '1999-11-25',
#                '1999-11-26', '1999-11-27',
#                ...
#                '2017-11-01', '2017-11-02', '2017-11-03', '2017-11-04',
#                '2017-11-05', '2017-11-06', '2017-11-07', '2017-11-08',
#                '2017-11-09', '2017-11-10'],
#               dtype='datetime64[ns]', name='Date', length=6568, freq='D')

# %%
data.loc['2017-10-10']
# Out:
# Open                 66.68
# High                 66.86
# Low                  66.22
# Close                66.60
# Volume          1143075.00
# OpenInt               0.00
# prevDay              66.49
# OneDayChange          0.19
# Name: 2017-10-10 00:00:00, dtype: float64

# %%
data.reset_index();

# %%
data.head()
# Out:
#               Open    High     Low   Close    Volume  OpenInt  prevDay  \
# Date
# 1999-11-18  30.713  33.754  27.002  29.702  66277506        0      NaN
# 1999-11-19  28.986  29.027  26.872  27.257  16142920        0   30.713
# 1999-11-20  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-21  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0   28.986
#
#             OneDayChange
# Date
# 1999-11-18           NaN
# 1999-11-19        -1.727
# 1999-11-20         0.000
# 1999-11-21         0.000
# 1999-11-22        -1.100

# %%
data.set_index('Open').loc[30.713] #changin index and getting specific value
# Out:
#           High     Low   Close    Volume  OpenInt  prevDay  OneDayChange
# Open
# 30.713  33.754  27.002  29.702  66277506        0      NaN           NaN
# 30.713  31.221  29.958  30.713   4260349        0   30.842        -0.129

# %%
data.head()
# Out:
#               Open    High     Low   Close    Volume  OpenInt  prevDay  \
# Date
# 1999-11-18  30.713  33.754  27.002  29.702  66277506        0      NaN
# 1999-11-19  28.986  29.027  26.872  27.257  16142920        0   30.713
# 1999-11-20  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-21  28.986  29.027  26.872  27.257  16142920        0   28.986
# 1999-11-22  27.886  29.702  27.044  29.702   6970266        0   28.986
#
#             OneDayChange
# Date
# 1999-11-18           NaN
# 1999-11-19        -1.727
# 1999-11-20         0.000
# 1999-11-21         0.000
# 1999-11-22        -1.100
